# %%
import pandas

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
prefs = pandas.read_table('/Users/dcl9/Data/tf-dna-preferences/results/bigbeds/hg38_Elk1_0004_vs_Ets1_0005-prefs.bed', names=['pref'])

# %%
type(prefs['pref'])
# Out:
# pandas.core.series.Series

# %%
ser = prefs['pref']

# %%
sampled = ser.sample(n=500000)

# %%
sampled[sampled<0].plot(kind='kde')

# %%
sampled[sampled>0].plot(kind='kde')

# %%
sampled[sampled>0].describe()
# Out:
# count    317099.000000
# mean          8.655605
# std           3.703954
# min           2.580000
# 25%           5.510000
# 50%           8.470000
# 75%          11.490000
# max          22.790000
# Name: pref, dtype: float64

# %%
sampled[sampled<0].describe()
# Out:
# count    54476.000000
# mean        -4.835740
# std          1.852404
# min        -15.920000
# 25%         -5.790000
# 50%         -4.400000
# 75%         -3.390000
# max         -2.580000
# Name: pref, dtype: float64

# %%
neg_bins = pandas.qcut(prefs[prefs < 0], 9, retbins=True)[1]

# %%
neg_bins
# Out:
# array([-17.24,  -7.24,  -6.01,  -5.25,  -4.65,  -4.16,  -3.7 ,  -3.29,
#         -2.92,  -2.58])

# %%
pos_bins = pandas.qcut(prefs[prefs > 0], 9, retbins=True)[1]

# %%
pos_bins
# Out:
# array([  2.58,   3.9 ,   5.18,   6.44,   7.76,   9.17,  10.53,  11.86,
#         13.51,  25.3 ])

# %%
from matplotlib.pyplot import plot

# %%
plot(pos_bins)

# %%
plot(neg_bins)
